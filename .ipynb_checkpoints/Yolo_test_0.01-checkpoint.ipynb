# %%
import torch
from matplotlib import pyplot as plt
import numpy as np

# %%
pip install easyocr
# Out:
# Requirement already satisfied: easyocr in c:\users\broth\anaconda3\lib\site-packages (1.6.2)
# Requirement already satisfied: Shapely in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (2.0.0)
# Requirement already satisfied: numpy in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (1.20.3)
# Requirement already satisfied: Pillow in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (8.4.0)
# Requirement already satisfied: torch in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (1.13.1)
# Requirement already satisfied: scikit-image in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (0.18.3)
# Requirement already satisfied: python-bidi in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: pyclipper in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: PyYAML in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: scipy in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (1.7.1)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (4.5.4.60)
# Requirement already satisfied: torchvision>=0.5 in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (0.14.1)
# Requirement already satisfied: ninja in c:\users\broth\anaconda3\lib\site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: requests in c:\users\broth\anaconda3\lib\site-packages (from torchvision>=0.5->easyocr) (2.26.0)
# Requirement already satisfied: typing-extensions in c:\users\broth\anaconda3\lib\site-packages (from torchvision>=0.5->easyocr) (3.10.0.2)
# Requirement already satisfied: six in c:\users\broth\anaconda3\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in c:\users\broth\anaconda3\lib\site-packages (from scikit-image->easyocr) (3.4.3)
# Requirement already satisfied: networkx>=2.0 in c:\users\broth\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.6.3)
# Requirement already satisfied: imageio>=2.3.0 in c:\users\broth\anaconda3\lib\site-packages (from scikit-image->easyocr) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\broth\anaconda3\lib\site-packages (from scikit-image->easyocr) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\broth\anaconda3\lib\site-packages (from scikit-image->easyocr) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\broth\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\broth\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\broth\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\broth\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->easyocr) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\broth\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\broth\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\broth\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\broth\anaconda3\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imutils
# Out:
# Requirement already satisfied: imutils in c:\users\broth\anaconda3\lib\site-packages (0.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ISR --no-deps
# Out:
# Collecting ISR
#   Using cached ISR-2.2.0-py3-none-any.whl (33 kB)
# Installing collected packages: ISR
# Successfully installed ISR-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\broth\anaconda3\lib\site-packages (2.11.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.12.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.2.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.10.0.2)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: setuptools in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (58.0.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.20.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: six>=1.12.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.30.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.1.21)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: packaging in c:\users\broth\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\broth\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.37.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\broth\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\broth\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\broth\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\broth\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\broth\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.26.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\broth\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\broth\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\broth\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\broth\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\broth\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.8.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\broth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\broth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\broth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\broth\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\broth\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\broth\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\broth\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %%
pip install opencv-contrib-python==4.5.5.62
# Out:
# Requirement already satisfied: opencv-contrib-python==4.5.5.62 in c:\users\broth\anaconda3\lib\site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\broth\anaconda3\lib\site-packages (from opencv-contrib-python==4.5.5.62) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\broth\anaconda3\lib\site-packages (4.5.5.62)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.14.5 in c:\users\broth\anaconda3\lib\site-packages (from opencv-contrib-python) (1.20.3)

# %%
import os
import time
import uuid
from PIL import Image
import torchvision
import torchvision.transforms.functional as F
import torchvision.transforms as T

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\broth/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-1-29 Python-3.9.7 torch-1.13.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
# img = 'G:/CSE_498r/project/dataset/images/DSC_0460.JPG'

# %%
# result = model(img)
# result.print()

# %%
# %matplotlib inline 
# plt.imshow(np.squeeze(result.render()))
# plt.show()

# %%
# !cd yolov5 && python train.py --img 640 --batch 32 --epochs 200 --data dataset.yml --weights yolov5s.pt --workers 2 --device 1

# %%
# !cd yolov5 && python train.py --img 640 --batch 12 --epochs 300 --data dataset.yml --weights yolov5s.pt --workers 2 --device 1

# %%
model01 = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp22/weights/last.pt')
# Out:
# Using cache found in C:\Users\broth/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-1-29 Python-3.9.7 torch-1.13.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients
# Adding AutoShape...

# %%
#image = cv2.imread('G:/CSE_498r/project/g_MG_0806.JPG')
image = cv2.imread('g_MG_0806.JPG')

# %%
result = model01(image)
result.print()
# Out:
# image 1/1: 3456x5184 1 license-plate
# Speed: 4.0ms pre-process, 183.5ms inference, 2.0ms NMS per image at shape (1, 3, 448, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(result.render()))
plt.show()

# %%
result.pandas().xyxy[0]
# Out:
#         xmin         ymin         xmax         ymax  confidence  class  \
# 0  2427.9104  1967.391724  2848.901855  2181.733887    0.966565      0
#
#             name
# 0  license-plate

# %%
location = result.xyxy[0][0]
location_arr = []

# %%
for bound in location:
    location_arr.append(int(bound.item()))

# %%
location_arr
# Out:
# [2427, 1967, 2848, 2181, 0, 0]

# %%
location_arr = location_arr[:4]

# %%
ncopy_img  = image.copy()
cv2.rectangle(ncopy_img, (location_arr[0], location_arr[1]), (location_arr[2], location_arr[3]), (255,0,0), 5)

# %matplotlib inline 

plt.imshow(cv2.cvtColor(ncopy_img, cv2.COLOR_BGR2RGB))

# %%
cropped_image  = image[location_arr[1]:location_arr[3], location_arr[0]:location_arr[2]]

# %matplotlib inline 

plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
#Image upscaling using ISR


from ISR.models import RDN

img = cv2.cvtColor(np.array(cropped_image), cv2.COLOR_RGB2BGR)
lr_img = np.array(img)

rdn = RDN(weights='psnr-small')
sr_img = rdn.predict(lr_img)
Image.fromarray(sr_img)
# Out:
# 1/1 [==============================] - 4s 4s/step
# <PIL.Image.Image image mode=RGB size=842x428 at 0x1EE4752ED90>

# %%
# Sharp process 1 (not good enough)

filter = np.array([[-1, -1, -1], [-1, 9, -1], [-1, -1, -1]])
# Applying cv2.filter2D function
sharpen_img = cv2.filter2D(sr_img,-1,filter)
plt.imshow(cv2.cvtColor(sharpen_img, cv2.COLOR_BGR2RGB))

# %%
# sharp process 2 (not good enough)

kernel = np.array([[-1, -1, -1],[-1, 9, -1],[-1, -1, -1]], np.float32) 

kernel = 1/3 * kernel

shrp_img = cv2.filter2D(cropped_image, -1, kernel)
plt.imshow(cv2.cvtColor(shrp_img, cv2.COLOR_BGR2RGB))

# %%
# using PIL and Tensorflow sharpening (not good enough yet)

img_pil = T.ToPILImage()(sr_img)
sharp_pil = F.adjust_sharpness(img_pil, 7.0) #tweak this
sharp_img = cv2.cvtColor(np.array(sharp_pil), cv2.COLOR_RGB2BGR)
plt.imshow(cv2.cvtColor(sharp_img, cv2.COLOR_BGR2RGB))

# %%
# sharp filter 3 (not good enough)

sharpen_filter = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])
sharped_img = cv2.filter2D(cropped_image, -1, sharpen_filter)
plt.imshow(cv2.cvtColor(sharped_img, cv2.COLOR_BGR2GRAY))

# %%
# using adaptive threshold (not good enough)

cropped = cv2.cvtColor(sr_img, cv2.COLOR_BGR2GRAY)
adaptive = cv2.adaptiveThreshold(cropped, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 81,4)
plt.imshow(cv2.cvtColor(adaptive, cv2.COLOR_BGR2RGB))

# %%
reader = easyocr.Reader(['bn'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
#result = reader.readtext(cropped_img)
result = reader.readtext(sharp_img, detail=1, paragraph=True) #change img variable from here
print(result)
# Out:
# [[[[20, 65], [811, 65], [811, 403], [20, 403]], 'ঢা4া বেড্রেৌগ ২১-৯০৮৭']]

# %%
x = location.xcenter[0]
y = location.ycenter[0]
w = location.width[0]
h = location.height[0]

# %%
x

# %%
cropped_image = torchvision.transforms.functional.crop(image, x, y, h, w)

# %% [markdown]
# cropped_image = torchvision.transforms.functional.crop(img: image, top: x, left: y, height: h, width: w)

# %%
print(xmin[0])

# %%
(x1, y1) = (np.min(xmin), np.min(ymin))
(x2, y2) = (np.max(xmax), np.max(ymax))

cropped_img = img[x1:x2+1, y1:y2+1]

# %%
# result.save(save_dir='G:/CSE_498r/project2/')

# %%
# torch.save(model01, 'G:/CSE_498r/project/model.py')
path = "G:/CSE_498r/project/vid_test02.mp4"

# %%
# !cd yolov5 && python model01 --source path

# %%
# Open the video
cap = cv2.VideoCapture("vid_test02.mp4")
ret, frame = cap.read()

cap.release()

# %%
result = model01(frame)

# %%
result.print()

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(result.render()))
plt.show()

# %%
result.crop(save=True, save_dir='G:/CSE_498r/project/test_vid', exist_ok=False)

# %%
# ret, frame = cap.read()

# cap.release()
    
# plt.imshow(frame[:,:,::-1]) # OpenCV uses BGR, whereas matplotlib uses RGB
# plt.show()

# %%
# # Get the frames per second (fps) of the video
# fps = cap.get(cv2.CAP_PROP_FPS)

# # Define the codec and create a video writer object
# # fourcc = cv2.VideoWriter_fourcc(*"mp4v")
# # out = cv2.VideoWriter("output.mp4", fourcc, fps, (640, 352))

# # Loop through each frame of the video
# while cap.isOpened():
#     # Read the next frame
#     ret, frame = cap.read()

#     # Break if the video has ended
#     if not ret:
#         break

#     # Preprocess the frame
# #     frame = preprocess(frame)

#     # Convert the frame to a PyTorch tensor
#     frame = torch.from_numpy(frame).unsqueeze(0)

#     # Run the frame through the model
#     output = model01(frame)

#     # Postprocess the output
#     output = postprocess(output)

#     # Write the output frame to the video
#     out.write(output)

# # Release the video objects
# cap.release()
# out.release()
